# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler

# %%
df = pd.read_csv('FormattedData.csv')

df.drop(columns=['LLL1 Index'], inplace=True)

print("Shape", df.shape)
print("Head")
display(df.head())
df.info()
# Out:
# Shape (1148, 57)
# Head
#         Date  XAU BGNL Curncy  ECSURPUS Index  BDIY Index  CRY Index  \
# 0  4/27/1999           282.25             NaN       995.0     134.65
# 1   5/4/1999           285.55             NaN      1095.0     139.04
# 2  5/11/1999           278.25             NaN      1121.0     136.78
# 3  5/18/1999           273.95             NaN      1061.0     133.90
# 4  5/25/1999           271.45             NaN      1017.0     132.09
#
#    DXY Curncy  JPY Curncy  GBP Curncy  Cl1 Comdty  VIX Index  ...  RX1 Comdty  \
# 0      100.63      120.44       1.617       17.81      23.36  ...      115.76
# 1      100.68      120.77       1.626       18.92      25.62  ...      115.11
# 2      100.24      121.07       1.621       18.06      25.62  ...      114.60
# 3      100.72      123.21       1.621       17.11      27.26  ...      114.24
# 4      101.38      122.85       1.602       17.14      28.90  ...      114.79
#
#    TY1 Comdty  GC1 Comdty  CO1 Comdty  ES1 Index  VG1 Index  NQ1 Index  \
# 0     115.563       282.3       15.80    1376.50     3726.0        NaN
# 1     114.313       286.9       16.93    1343.00     3740.0        NaN
# 2     113.344       278.8       15.96    1358.25     3690.0        NaN
# 3     112.344       274.2       15.14    1341.25     3595.0        NaN
# 4     113.125       270.8       15.43    1284.50     3631.0        NaN
#
#    TP1 Index  DU1 Comdty  TU2 Comdty
# 0     1347.5      105.69     104.898
# 1     1328.5      105.58     104.664
# 2     1343.5      105.67     104.406
# 3     1323.5      105.60     104.141
# 4     1307.0      105.68     104.289
#
# [5 rows x 57 columns]
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1148 entries, 0 to 1147
# Data columns (total 57 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Date             1148 non-null   object
#  1   XAU BGNL Curncy  1148 non-null   float64
#  2   ECSURPUS Index   1111 non-null   float64
#  3   BDIY Index       1148 non-null   float64
#  4   CRY Index        1148 non-null   float64
#  5   DXY Curncy       1148 non-null   float64
#  6   JPY Curncy       1148 non-null   float64
#  7   GBP Curncy       1148 non-null   float64
#  8   Cl1 Comdty       1148 non-null   float64
#  9   VIX Index        1148 non-null   float64
#  10  USGG30YR Index   1148 non-null   float64
#  11  GT10 Govt        1148 non-null   float64
#  12  USGG2YR Index    1148 non-null   float64
#  13  USGG3M Index     1148 non-null   float64
#  14  US0001M Index    1148 non-null   float64
#  15  GTDEM30Y Govt    1148 non-null   float64
#  16  GTDEM10Y Govt    1148 non-null   float64
#  17  GTDEM2Y Govt     1148 non-null   float64
#  18  EONIA Index      1148 non-null   float64
#  19  GTITL30YR Corp   1121 non-null   float64
#  20  GTITL10YR Corp   1121 non-null   float64
#  21  GTITL2YR Corp    1121 non-null   float64
#  22  GTJPY30YR Corp   1129 non-null   float64
#  23  GTJPY10YR Corp   1148 non-null   float64
#  24  GTJPY2YR Corp    1148 non-null   float64
#  25  GTGBP30Y Govt    1148 non-null   float64
#  26  GTGBP20Y Govt    1148 non-null   float64
#  27  GTGBP2Y Govt     1148 non-null   float64
#  28  LUMSTRUU Index   1148 non-null   float64
#  29  LMBITR Index     1148 non-null   float64
#  30  LUACTRUU Index   1148 non-null   float64
#  31  LF98TRUU Index   1148 non-null   float64
#  32  LG30TRUU Index   1148 non-null   float64
#  33  LP01TREU Index   1148 non-null   float64
#  34  EMUSTRUU Index   1148 non-null   float64
#  35  LF94TRUU Index   1147 non-null   float64
#  36  MXUS Index       1148 non-null   float64
#  37  MXEU Index       1148 non-null   float64
#  38  MXJP Index       1148 non-null   float64
#  39  MXBR Index       1148 non-null   float64
#  40  MXRU Index       1148 non-null   float64
#  41  MXIN Index       1148 non-null   float64
#  42  MXCN Index       1148 non-null   float64
#  43  MXWO Index       1148 non-null   float64
#  44  MXWD Index       1148 non-null   float64
#  45  LEGATRUU Index   1148 non-null   float64
#  46  HFRXGL Index     1147 non-null   float64
#  47  RX1 Comdty       1148 non-null   float64
#  48  TY1 Comdty       1148 non-null   float64
#  49  GC1 Comdty       1148 non-null   float64
#  50  CO1 Comdty       1148 non-null   float64
#  51  ES1 Index        1148 non-null   float64
#  52  VG1 Index        1148 non-null   float64
#  53  NQ1 Index        1140 non-null   float64
#  54  TP1 Index        1148 non-null   float64
#  55  DU1 Comdty       1148 non-null   float64
#  56  TU2 Comdty       1148 non-null   float64
# dtypes: float64(56), object(1)
# memory usage: 511.3+ KB

# %%
df['Pct_Change'] = df['MXWO Index'].pct_change(periods=-1) * 100
df['CRASH'] = (df['Pct_Change'] <= -5).astype(int)

# %%
print(df['CRASH'].value_counts())
# Out:
# CRASH
# 0    1132
# 1      16
# Name: count, dtype: int64

# %%
print(df.isnull().sum())
# Out:
# Date                0
# XAU BGNL Curncy     0
# ECSURPUS Index     37
# BDIY Index          0
# CRY Index           0
# DXY Curncy          0
# JPY Curncy          0
# GBP Curncy          0
# Cl1 Comdty          0
# VIX Index           0
# USGG30YR Index      0
# GT10 Govt           0
# USGG2YR Index       0
# USGG3M Index        0
# US0001M Index       0
# GTDEM30Y Govt       0
# GTDEM10Y Govt       0
# GTDEM2Y Govt        0
# EONIA Index         0
# GTITL30YR Corp     27
# GTITL10YR Corp     27
# GTITL2YR Corp      27
# GTJPY30YR Corp     19
# GTJPY10YR Corp      0
# GTJPY2YR Corp       0
# GTGBP30Y Govt       0
# GTGBP20Y Govt       0
# GTGBP2Y Govt        0
# LUMSTRUU Index      0
# LMBITR Index        0
# LUACTRUU Index      0
# LF98TRUU Index      0
# LG30TRUU Index      0
# LP01TREU Index      0
# EMUSTRUU Index      0
# LF94TRUU Index      1
# MXUS Index          0
# MXEU Index          0
# MXJP Index          0
# MXBR Index          0
# MXRU Index          0
# MXIN Index          0
# MXCN Index          0
# MXWO Index          0
# MXWD Index          0
# LEGATRUU Index      0
# HFRXGL Index        1
# RX1 Comdty          0
# TY1 Comdty          0
# GC1 Comdty          0
# CO1 Comdty          0
# ES1 Index           0
# VG1 Index           0
# NQ1 Index           8
# TP1 Index           0
# DU1 Comdty          0
# TU2 Comdty          0
# Pct_Change          1
# CRASH               0
# dtype: int64

# %%
df['ECSURPUS Index'].fillna(0, inplace=True)
# Out:
# <ipython-input-9-5600619e3a2a>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['ECSURPUS Index'].fillna(0, inplace=True)

# %%
print(df.isnull().sum())
# Out:
# Date                0
# XAU BGNL Curncy     0
# ECSURPUS Index      0
# BDIY Index          0
# CRY Index           0
# DXY Curncy          0
# JPY Curncy          0
# GBP Curncy          0
# Cl1 Comdty          0
# VIX Index           0
# USGG30YR Index      0
# GT10 Govt           0
# USGG2YR Index       0
# USGG3M Index        0
# US0001M Index       0
# GTDEM30Y Govt       0
# GTDEM10Y Govt       0
# GTDEM2Y Govt        0
# EONIA Index         0
# GTITL30YR Corp     27
# GTITL10YR Corp     27
# GTITL2YR Corp      27
# GTJPY30YR Corp     19
# GTJPY10YR Corp      0
# GTJPY2YR Corp       0
# GTGBP30Y Govt       0
# GTGBP20Y Govt       0
# GTGBP2Y Govt        0
# LUMSTRUU Index      0
# LMBITR Index        0
# LUACTRUU Index      0
# LF98TRUU Index      0
# LG30TRUU Index      0
# LP01TREU Index      0
# EMUSTRUU Index      0
# LF94TRUU Index      1
# MXUS Index          0
# MXEU Index          0
# MXJP Index          0
# MXBR Index          0
# MXRU Index          0
# MXIN Index          0
# MXCN Index          0
# MXWO Index          0
# MXWD Index          0
# LEGATRUU Index      0
# HFRXGL Index        1
# RX1 Comdty          0
# TY1 Comdty          0
# GC1 Comdty          0
# CO1 Comdty          0
# ES1 Index           0
# VG1 Index           0
# NQ1 Index           8
# TP1 Index           0
# DU1 Comdty          0
# TU2 Comdty          0
# Pct_Change          1
# CRASH               0
# dtype: int64

# %%
df.fillna(method='ffill', inplace=True)
# Out:
# <ipython-input-11-e9443599d05e>:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method='ffill', inplace=True)

# %%
df.fillna(method='bfill', inplace=True)
# Out:
# <ipython-input-12-168d8f9d469d>:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method='bfill', inplace=True)

# %%
# Define columns for which to create lagged features
columns_to_lag = ['VIX Index', 'MXWO Index']

# Number of lags to create
num_lags = 3  # 1-week, 2-week, 3-week lags

# Create lagged features
for col in columns_to_lag:
    for lag in range(1, num_lags + 1):
        df[f'{col}_lag_{lag}'] = df[col].shift(lag)

# %%
df
# Out:
#            Date  XAU BGNL Curncy  ECSURPUS Index  BDIY Index  CRY Index  \
# 0     4/27/1999           282.25           0.000       995.0    134.650
# 1      5/4/1999           285.55           0.000      1095.0    139.040
# 2     5/11/1999           278.25           0.000      1121.0    136.780
# 3     5/18/1999           273.95           0.000      1061.0    133.900
# 4     5/25/1999           271.45           0.000      1017.0    132.090
# ...         ...              ...             ...         ...        ...
# 1143  3/23/2021          1727.96           0.339      2271.0    184.502
# 1144  3/30/2021          1685.56           0.303      2103.0    184.874
# 1145   4/6/2021          1743.28           0.440      2092.0    185.839
# 1146  4/13/2021          1742.69           0.467      2140.0    188.137
# 1147  4/20/2021          1779.72           0.492      2432.0    193.804
#
#       DXY Curncy  JPY Curncy  GBP Curncy  Cl1 Comdty  VIX Index  ...  \
# 0        100.630      120.44       1.617       17.81      23.36  ...
# 1        100.680      120.77       1.626       18.92      25.62  ...
# 2        100.240      121.07       1.621       18.06      25.62  ...
# 3        100.720      123.21       1.621       17.11      27.26  ...
# 4        101.380      122.85       1.602       17.14      28.90  ...
# ...          ...         ...         ...         ...        ...  ...
# 1143      92.336      108.72       1.376       57.76      20.30  ...
# 1144      93.297      110.29       1.372       60.55      19.61  ...
# 1145      92.335      109.88       1.382       59.33      18.12  ...
# 1146      91.852      109.19       1.374       60.18      16.65  ...
# 1147      91.147      108.09       1.395       62.50      18.46  ...
#
#       DU1 Comdty  TU2 Comdty  Pct_Change  CRASH  VIX Index_lag_1  \
# 0        105.690     104.898    1.549891      0              NaN
# 1        105.580     104.664   -0.548480      0            23.36
# 2        105.670     104.406    2.276027      0            25.62
# 3        105.600     104.141    2.262566      0            25.62
# 4        105.680     104.289   -0.105340      0            27.26
# ...          ...         ...         ...    ...              ...
# 1143     112.140     110.383   -0.609247      0            19.79
# 1144     112.090     110.387   -2.473029      0            20.30
# 1145     112.120     110.281   -1.437878      0            19.61
# 1146     112.115     110.293   -0.878382      0            18.12
# 1147     112.100     110.293   -0.878382      0            16.65
#
#       VIX Index_lag_2  VIX Index_lag_3  MXWO Index_lag_1  MXWO Index_lag_2  \
# 0                 NaN              NaN               NaN               NaN
# 1                 NaN              NaN           1252.10               NaN
# 2               23.36              NaN           1232.99           1252.10
# 3               25.62            23.36           1239.79           1232.99
# 4               25.62            25.62           1212.20           1239.79
# ...               ...              ...               ...               ...
# 1143            24.03            24.10           2823.69           2761.82
# 1144            19.79            24.03           2788.01           2823.69
# 1145            20.30            19.79           2805.10           2788.01
# 1146            19.61            20.30           2876.23           2805.10
# 1147            18.12            19.61           2918.19           2876.23
#
#       MXWO Index_lag_3
# 0                  NaN
# 1                  NaN
# 2                  NaN
# 3              1252.10
# 4              1232.99
# ...                ...
# 1143           2768.25
# 1144           2761.82
# 1145           2823.69
# 1146           2788.01
# 1147           2805.10
#
# [1148 rows x 65 columns]

# %% [markdown]
# Now time to normalize with Min-Max Scaling
# We choose Min-Max scaling because our data has a defined range

# %%
from sklearn.preprocessing import MinMaxScaler

# Columns to normalize (exclude 'CRASH' and 'Date')
columns_to_normalize = [col for col in df.columns if col not in ['Date', 'CRASH']]

# Initialize the scaler
scaler = MinMaxScaler()

# Apply scaling to the selected columns
df[columns_to_normalize] = scaler.fit_transform(df[columns_to_normalize])

# %%
df
# Out:
#            Date  XAU BGNL Curncy  ECSURPUS Index  BDIY Index  CRY Index  \
# 0     4/27/1999         0.016425        0.495674    0.061207   0.078491
# 1      5/4/1999         0.018307        0.495674    0.069901   0.090642
# 2     5/11/1999         0.014143        0.495674    0.072161   0.084387
# 3     5/18/1999         0.011691        0.495674    0.066945   0.076415
# 4     5/25/1999         0.010265        0.495674    0.063119   0.071405
# ...         ...              ...             ...         ...        ...
# 1143  3/23/2021         0.840915        0.668193    0.172144   0.216479
# 1144  3/30/2021         0.816734        0.649873    0.157538   0.217509
# 1145   4/6/2021         0.849652        0.719593    0.156581   0.220180
# 1146  4/13/2021         0.849315        0.733333    0.160755   0.226541
# 1147  4/20/2021         0.870433        0.746056    0.186142   0.242227
#
#       DXY Curncy  JPY Curncy  GBP Curncy  Cl1 Comdty  VIX Index  ...  \
# 0       0.604256    0.758221    0.487404    0.059560   0.209537  ...
# 1       0.605288    0.763844    0.497262    0.068036   0.243532  ...
# 2       0.596214    0.768956    0.491785    0.061469   0.243532  ...
# 3       0.606112    0.805418    0.491785    0.054215   0.268201  ...
# 4       0.619723    0.799284    0.470975    0.054444   0.292870  ...
# ...          ...         ...         ...         ...        ...  ...
# 1143    0.433214    0.558528    0.223439    0.364615   0.163508  ...
# 1144    0.453033    0.585279    0.219058    0.385919   0.153129  ...
# 1145    0.433194    0.578293    0.230011    0.376604   0.130716  ...
# 1146    0.423233    0.566536    0.221249    0.383094   0.108604  ...
# 1147    0.408694    0.547793    0.244250    0.400809   0.135830  ...
#
#       DU1 Comdty  TU2 Comdty  Pct_Change  CRASH  VIX Index_lag_1  \
# 0       0.390286    0.542358    0.478313      0              NaN
# 1       0.380746    0.523333    0.401156      0         0.209537
# 2       0.388552    0.502358    0.505014      0         0.243532
# 3       0.382480    0.480813    0.504519      0         0.243532
# 4       0.389419    0.492846    0.417451      0         0.268201
# ...          ...         ...         ...    ...              ...
# 1143    0.949696    0.988293    0.398922      0         0.155836
# 1144    0.945360    0.988618    0.330390      0         0.163508
# 1145    0.947962    0.980000    0.368453      0         0.153129
# 1146    0.947528    0.980976    0.389026      0         0.130716
# 1147    0.946227    0.980976    0.389026      0         0.108604
#
#       VIX Index_lag_2  VIX Index_lag_3  MXWO Index_lag_1  MXWO Index_lag_2  \
# 0                 NaN              NaN               NaN               NaN
# 1                 NaN              NaN          0.247081               NaN
# 2            0.209537              NaN          0.238445          0.251856
# 3            0.243532         0.209537          0.241518          0.243054
# 4            0.243532         0.243532          0.229050          0.246186
# ...               ...              ...               ...               ...
# 1143         0.219615         0.220668          0.957295          0.947298
# 1144         0.155836         0.219615          0.941171          0.975798
# 1145         0.163508         0.155836          0.948894          0.959362
# 1146         0.153129         0.163508          0.981038          0.967234
# 1147         0.130716         0.153129          1.000000          1.000000
#
#       MXWO Index_lag_3
# 0                  NaN
# 1                  NaN
# 2                  NaN
# 3             0.257561
# 4             0.248559
# ...                ...
# 1143          0.971783
# 1144          0.968754
# 1145          0.997899
# 1146          0.981091
# 1147          0.989142
#
# [1148 rows x 65 columns]

# %%
# Drop rows with NaN values
df.dropna(inplace=True)

# Reset the index after dropping rows
df.reset_index(drop=True, inplace=True)

# %%
df
# Out:
#            Date  XAU BGNL Curncy  ECSURPUS Index  BDIY Index  CRY Index  \
# 0     5/18/1999         0.011691        0.495674    0.066945   0.076415
# 1     5/25/1999         0.010265        0.495674    0.063119   0.071405
# 2      6/1/1999         0.007813        0.495674    0.059468   0.067641
# 3      6/8/1999         0.004676        0.495674    0.062859   0.082588
# 4     6/15/1999         0.003593        0.495674    0.062859   0.086186
# ...         ...              ...             ...         ...        ...
# 1140  3/23/2021         0.840915        0.668193    0.172144   0.216479
# 1141  3/30/2021         0.816734        0.649873    0.157538   0.217509
# 1142   4/6/2021         0.849652        0.719593    0.156581   0.220180
# 1143  4/13/2021         0.849315        0.733333    0.160755   0.226541
# 1144  4/20/2021         0.870433        0.746056    0.186142   0.242227
#
#       DXY Curncy  JPY Curncy  GBP Curncy  Cl1 Comdty  VIX Index  ...  \
# 0       0.606112    0.805418    0.491785    0.054215   0.268201  ...
# 1       0.619723    0.799284    0.470975    0.054444   0.292870  ...
# 2       0.633953    0.758392    0.481928    0.048335   0.258574  ...
# 3       0.627560    0.737945    0.474261    0.058415   0.219465  ...
# 4       0.636840    0.762651    0.458927    0.065211   0.247894  ...
# ...          ...         ...         ...         ...        ...  ...
# 1140    0.433214    0.558528    0.223439    0.364615   0.163508  ...
# 1141    0.453033    0.585279    0.219058    0.385919   0.153129  ...
# 1142    0.433194    0.578293    0.230011    0.376604   0.130716  ...
# 1143    0.423233    0.566536    0.221249    0.383094   0.108604  ...
# 1144    0.408694    0.547793    0.244250    0.400809   0.135830  ...
#
#       DU1 Comdty  TU2 Comdty  Pct_Change  CRASH  VIX Index_lag_1  \
# 0       0.382480    0.480813    0.504519      0         0.243532
# 1       0.389419    0.492846    0.417451      0         0.268201
# 2       0.353859    0.456016    0.338040      0         0.292870
# 3       0.356461    0.451545    0.436590      0         0.258574
# 4       0.326106    0.438211    0.346166      0         0.219465
# ...          ...         ...         ...    ...              ...
# 1140    0.949696    0.988293    0.398922      0         0.155836
# 1141    0.945360    0.988618    0.330390      0         0.163508
# 1142    0.947962    0.980000    0.368453      0         0.153129
# 1143    0.947528    0.980976    0.389026      0         0.130716
# 1144    0.946227    0.980976    0.389026      0         0.108604
#
#       VIX Index_lag_2  VIX Index_lag_3  MXWO Index_lag_1  MXWO Index_lag_2  \
# 0            0.243532         0.209537          0.241518          0.243054
# 1            0.243532         0.243532          0.229050          0.246186
# 2            0.268201         0.243532          0.216929          0.233477
# 3            0.292870         0.268201          0.217494          0.221122
# 4            0.258574         0.292870          0.229922          0.221698
# ...               ...              ...               ...               ...
# 1140         0.219615         0.220668          0.957295          0.947298
# 1141         0.155836         0.219615          0.941171          0.975798
# 1142         0.163508         0.155836          0.948894          0.959362
# 1143         0.153129         0.163508          0.981038          0.967234
# 1144         0.130716         0.153129          1.000000          1.000000
#
#       MXWO Index_lag_3
# 0             0.257561
# 1             0.248559
# 2             0.251762
# 3             0.238765
# 4             0.226131
# ...                ...
# 1140          0.971783
# 1141          0.968754
# 1142          0.997899
# 1143          0.981091
# 1144          0.989142
#
# [1145 rows x 65 columns]

# %%
import seaborn as sns # Assuming you want to use seaborn for the heatmap
import matplotlib.pyplot as plt

# Ensure 'Date' is excluded, not 'Data'
columns_to_correlate = df.columns.difference(['Date', 'CRASH'])

# Calculate the correlation matrix only on numerical columns
correlation_matrix = df[columns_to_correlate].corr()

# Plotting the heatmap
plt.figure(figsize=(40, 32))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Matrix of Financial Market Data')
plt.show()

# %% [markdown]
# Time to split the data

# %%
# Define the split ratio (80% training, 20% testing)
split_ratio = 0.8

# Determine the split index
split_index = int(len(df) * split_ratio)

# Split the data
train_data = df.iloc[:split_index]
test_data = df.iloc[split_index:]

# Separate features and target variable
X_train = train_data.drop(columns=['Date', 'CRASH'])
y_train = train_data['CRASH']

X_test = test_data.drop(columns=['Date', 'CRASH'])
y_test = test_data['CRASH']

# %%
print(f"Training set size: {X_train.shape[0]} rows")
print(f"Testing set size: {X_test.shape[0]} rows")
# Out:
# Training set size: 916 rows
# Testing set size: 229 rows

# %% [markdown]
# Time to train the model

# %%
X_train = X_train.drop(columns=['Pct_Change'])
X_test = X_test.drop(columns=['Pct_Change'])

# %%
from xgboost import XGBClassifier
from sklearn.metrics import classification_report, roc_auc_score

# Initialize the XGBoost classifier
model = XGBClassifier(
    n_estimators=100,  # Number of trees
    learning_rate=0.1,  # Step size
    max_depth=3,  # Maximum tree depth
    random_state=42  # Reproducibility
)

# Train the model
model.fit(X_train, y_train)

# Predict on the test set
y_pred = model.predict(X_test)
y_pred_proba = model.predict_proba(X_test)[:, 1]  # Confidence scores for CRASH (1)

# Evaluate the model
print("Classification Report:")
print(classification_report(y_test, y_pred))

# Compute and display the ROC-AUC score
roc_auc = roc_auc_score(y_test, y_pred_proba)
print(f"ROC-AUC Score: {roc_auc:.2f}")
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99       226
#            1       0.00      0.00      0.00         3
#
#     accuracy                           0.99       229
#    macro avg       0.49      0.50      0.50       229
# weighted avg       0.97      0.99      0.98       229
#
# ROC-AUC Score: 0.99
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
print(df['CRASH'].value_counts())
# Out:
# CRASH
# 0    1129
# 1      16
# Name: count, dtype: int64

# %%
crash_row = df[df['CRASH'] == 1]
print(crash_row)
# Out:
#             Date  XAU BGNL Curncy  ECSURPUS Index  BDIY Index  CRY Index  \
# 43     3/14/2000         0.020616        0.744020    0.117719   0.192033
# 166    7/23/2002         0.034389        0.679389    0.059207   0.173598
# 177    10/8/2002         0.037127        0.425954    0.091897   0.210412
# 199    3/11/2003         0.055348        0.435115    0.128152   0.311941
# 493   10/28/2008         0.274936        0.296183    0.060077   0.422742
# 512    3/10/2009         0.365352        0.084478    0.174491   0.280524
# 513    3/17/2009         0.377482        0.096692    0.146322   0.304938
# 519    4/28/2009         0.364993        0.396947    0.130325   0.307041
# 530    7/14/2009         0.382843        0.745547    0.243958   0.359577
# 577     6/8/2010         0.564855        0.708397    0.285863   0.397997
# 581     7/6/2010         0.536283        0.482952    0.159624   0.408293
# 646    10/4/2011         0.780195        0.366921    0.138585   0.517572
# 854    9/29/2015         0.500365        0.227990    0.055208   0.241593
# 1088   3/24/2020         0.783827        0.656997    0.027126   0.060513
# 1090    4/7/2020         0.797646        0.675827    0.026517   0.059960
# 1120   11/3/2020         0.944196        0.937913    0.084507   0.112739
#
#       DXY Curncy  JPY Curncy  GBP Curncy  Cl1 Comdty  VIX Index  ...  \
# 43      0.698501    0.492418    0.441402    0.165547   0.225331  ...
# 166     0.728609    0.702505    0.430449    0.124465   0.533845  ...
# 177     0.757687    0.824672    0.418401    0.148671   0.475181  ...
# 199     0.548164    0.700971    0.475356    0.203955   0.363718  ...
# 493     0.323751    0.349293    0.423877    0.402566   0.865373  ...
# 512     0.362913    0.386948    0.224535    0.272602   0.525572  ...
# 513     0.321792    0.387119    0.253012    0.298946   0.471871  ...
# 519     0.285187    0.349804    0.317634    0.304750   0.429001  ...
# 530     0.182611    0.293065    0.500548    0.378054   0.234507  ...
# 577     0.351921    0.262566    0.296824    0.473274   0.365072  ...
# 581     0.263018    0.195945    0.377875    0.473198   0.304152  ...
# 646     0.170506    0.015335    0.401972    0.501374   0.472172  ...
# 854     0.505785    0.745442    0.376780    0.268937   0.261733  ...
# 1088    0.633313    0.605384    0.000000    0.106903   0.785800  ...
# 1090    0.589202    0.560572    0.067908    0.104001   0.560620  ...
# 1120    0.458312    0.486625    0.144578    0.211133   0.392900  ...
#
#       DU1 Comdty  TU2 Comdty  Pct_Change  CRASH  VIX Index_lag_1  \
# 43      0.084996    0.052683    0.217388      1         0.223827
# 166     0.227233    0.115528    0.109774      1         0.409446
# 177     0.350390    0.115528    0.093854      1         0.371390
# 199     0.462272    0.791382    0.196235      1         0.336943
# 493     0.415438    0.702439    0.000000      1         0.657040
# 512     0.595403    0.826341    0.169509      1         0.624248
# 513     0.582827    0.822520    0.218347      1         0.525572
# 519     0.600173    0.804715    0.197168      1         0.416817
# 530     0.607112    0.791382    0.205193      1         0.322202
# 577     0.773634    0.883496    0.212781      1         0.392750
# 581     0.714657    0.889837    0.230977      1         0.371540
# 646     0.751518    0.965447    0.152419      1         0.425391
# 854     0.881180    0.920325    0.218425      1         0.195698
# 1088    0.939722    0.965691    0.202775      1         1.000000
# 1090    0.940590    0.971463    0.216532      1         0.663508
# 1120    0.977450    0.988293    0.219177      1         0.359807
#
#       VIX Index_lag_2  VIX Index_lag_3  MXWO Index_lag_1  MXWO Index_lag_2  \
# 43           0.209687         0.247142          0.294097          0.292614
# 166          0.312726         0.293773          0.057532          0.084901
# 177          0.467659         0.429904          0.022722          0.013580
# 199          0.335590         0.326113          0.016806          0.019513
# 493          0.687425         0.665614          0.120555          0.146134
# 512          0.542419         0.590102          0.000000          0.028763
# 513          0.624248         0.542419          0.008997          0.000000
# 519          0.424789         0.465704          0.068252          0.072095
# 530          0.254513         0.318141          0.101476          0.119168
# 577          0.378761         0.362816          0.164580          0.158083
# 581          0.265042         0.247292          0.154887          0.184193
# 646          0.352437         0.413357          0.196494          0.210325
# 854          0.197202         0.232702          0.404643          0.427780
# 1088         0.569645         0.412004          0.482452          0.620306
# 1090         0.785800         1.000000          0.518510          0.477806
# 1120         0.299639         0.250301          0.757533          0.791089
#
#       MXWO Index_lag_3
# 43            0.294446
# 166           0.081129
# 177           0.038119
# 199           0.029551
# 493           0.157514
# 512           0.043019
# 513           0.029414
# 519           0.060034
# 530           0.109742
# 577           0.191521
# 581           0.189839
# 646           0.202233
# 854           0.434210
# 1088          0.694427
# 1090          0.502916
# 1120          0.828542
#
# [16 rows x 65 columns]

# %%
from xgboost import plot_importance
import matplotlib.pyplot as plt

plot_importance(model)
plt.show()

# %%
plot_importance(model)
plt.show()

# %%
from imblearn.over_sampling import SMOTE

smote = SMOTE(random_state=42)
X_train_resampled, y_train_resampled = smote.fit_resample(X_train, y_train)

# %%
from imblearn.under_sampling import RandomUnderSampler

rus = RandomUnderSampler(random_state=42)
X_train_resampled, y_train_resampled = rus.fit_resample(X_train, y_train)

# %%
# Train the model with resampled data
model = XGBClassifier(random_state=42, eval_metric='aucpr')
model.fit(X_train_resampled, y_train_resampled)

# Make predictions
y_pred = model.predict(X_test)
y_pred_proba = model.predict_proba(X_test)[:, 1]

# Evaluate the model
from sklearn.metrics import classification_report, roc_auc_score
print("Classification Report:")
print(classification_report(y_test, y_pred))
print("ROC-AUC Score:", roc_auc_score(y_test, y_pred_proba))
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      0.84      0.91       226
#            1       0.08      1.00      0.14         3
#
#     accuracy                           0.84       229
#    macro avg       0.54      0.92      0.53       229
# weighted avg       0.99      0.84      0.90       229
#
# ROC-AUC Score: 0.9004424778761062

# %%
from xgboost import plot_importance
import matplotlib.pyplot as plt

plot_importance(model)
plt.show()

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

# Generate confusion matrix
cm = confusion_matrix(y_test, y_pred)

# Display confusion matrix
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=model.classes_)
disp.plot(cmap='Blues')

# %% [markdown]
# All done, we have our model that predicts the crashes all the time at the expense of relatively high false positive rate (36) in the test data.

# %%
import pickle

# Save the model to a file
with open('xgb_weights.pkl', 'wb') as file:
    pickle.dump(model, file)

print("Model saved")
# Out:
# Model saved
